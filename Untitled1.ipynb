# %%
from flask import Flask, render_template
app = Flask(__name__)
import tweepy
import pandas as pd
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
@app.route("/")
def index():
    data=pd.read_csv('example.csv')
    return data.to_html()

# %%
def twitter_setup():
    CONSUMER_KEY= "MzZDnnylYgqdRVFF53VGbI1tF"
    CONSUMER_SECRET="sTzQPdn5vGeErnwifT0RzPO4pByjn94j4R0qwDxjhZTA6iOaX8"
    ACCESS_TOKEN="1037130872120598529-freJpDKCC9dfnaJEbFILlTjm7J0B9X"
    ACCESS_SECRET="dI2qS0RxOud4IU9RFOEuJ9u3907E5Q3PjRwMa2HWnhCUu"
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN,ACCESS_SECRET)
    api=tweepy.API(auth)
    return api
extractor = twitter_setup()
tweets = extractor.user_timeline(screen_name="madapls",count=200)
print("numerosde twets extraidos \n".format(len(tweets)))
print("5 tweets mas recientes:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# numerosde twets extraidos
#
# 5 tweets mas recientes:
#
# Seguimos en directo antes de volar a Berlin a TwitchCon.
#
# https://t.co/k6WTTWZrn6
#
# Con DG88 en la Tormenta de Fuego del Quinto Campo de Batalla de Dado y Artes Electronicos.
#
# https://t.co/k6WTTWZrn6
#
# @Lopez74Jara @NVIDIAGeForceES @futurexpe Uff... Luce bestial! Disfrutala tio!
#
# RT @Lopez74Jara: Ya tengo esta bestia en casa!,me ha costado un poco domarla pero ya come de mi mano 😁 ..muchisimas gracias! @NVIDIAGeForce…
#
# @jlvillabriga Me coge un poco lejos, la verdad... Una pena, porque estoy ya de la comida inglesa hasta los bemoles!

# %%
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
data['longitud']=np.array([len(tweet.text)for tweet in tweets])
data['ID']=np.array([tweet.id for tweet in tweets])
data['fecha']=np.array([tweet.created_at for tweet in tweets])
data['fuente']=np.array([tweet.source for tweet in tweets])
data['likes']=np.array([tweet.favorite_count for tweet in tweets])
data['rts']=np.array([tweet.retweet_count for tweet in tweets])
data
# Out:
#                                                 Tweets  longitud  \
# 0    Seguimos en directo antes de volar a Berlin a ...        81
# 1    Con DG88 en la Tormenta de Fuego del Quinto Ca...       115
# 2    @Lopez74Jara @NVIDIAGeForceES @futurexpe Uff.....        77
# 3    RT @Lopez74Jara: Ya tengo esta bestia en casa!...       140
# 4    @jlvillabriga Me coge un poco lejos, la verdad...       115
# 5    Han abierto un supermercado cerca de mi casa y...       140
# 6       @StreamGameOVER Animo crack y a recuperarse ;)        46
# 7                  RT @LI3PeO: https://t.co/Mt539SJCOH        35
# 8    @ErikBusellato @RouzXIII @CooLifeGame https://...        61
# 9         @RouzXIII @aitorgval https://t.co/jW8NAxg7aM        44
# 10            @Elf4rw3N Muchas gracias matriculilla ;D        40
# 11                   @RouzXIII https://t.co/jRECLGw1KN        33
# 12   RT @RouzXIII: Otro encargo más para el majo de...       140
# ...

# %%
data.to_csv(index=False)
# Out:
# 'Tweets,longitud,ID,fecha,fuente,likes,rts\r\n"Seguimos en directo antes de volar a Berlin a TwitchCon.\n\nhttps://t.co/k6WTTWZrn6",81,1116059775593328640,2019-04-10 19:26:00,Twitter Web Client,16,3\r\n"Con DG88 en la Tormenta de Fuego del Quinto Campo de Batalla de Dado y Artes Electronicos.\n\nhttps://t.co/k6WTTWZrn6",115,1116042030940135425,2019-04-10 18:15:29,Twitter Web Client,31,6\r\n@Lopez74Jara @NVIDIAGeForceES @futurexpe Uff... Luce bestial! Disfrutala tio!,77,1116033048980676610,2019-04-10 17:39:48,Twitter Web Client,4,0\r\n"RT @Lopez74Jara: Ya tengo esta bestia en casa!,me ha costado un poco domarla pero ya come de mi mano 😁 ..muchisimas gracias! @NVIDIAGeForce…",140,1116032960048902146,2019-04-10 17:39:27,Twitter Web Client,0,18\r\n"@jlvillabriga Me coge un poco lejos, la verdad... Una pena, porque estoy ya de la comida inglesa hasta los bemoles!",115,1115947855976574976,2019-04-10 12:01:16,Twitter Web Client,2,0\r\nHan abierto un supermercado cerca de mi casa y estaba cu
# ...

# %%
data.to_csv('example.csv')

# %%
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2019-04-10 18:05:41,751] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\crist\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\crist\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\crist\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\crist\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
# ...
